# %% [markdown]
# # Variabel

# %% [markdown]
# Bersifat mutable (nilainya bisa berubah-ubah)

# %% [markdown]
# 1. Nama variabel boleh diawali menggunakan huruf atau garis bawah (_), contoh: nama, _nama, namaKu, nama_variabel.
#
# 2. Karakter selanjutnya dapat berupa huruf, garis bawah (_) atau angka, contoh: __nama, n2, nilai1.
#
# 3. Karakter pada nama variabel bersifat sensitif (case-sensitif). Artinya huruf besar dan kecil dibedakan. Misalnya, variabel_Ku dan variabel_ku, keduanya adalah variabel yang berbeda.
#
# 4. Nama variabel tidak boleh menggunakan kata kunci yang sudah ada dalam python seperti if, while, for, dsb.

# %%
# Struktur:
# nama_variabel = <nilai>

# %%
# Contoh
makanan = "Pizza"
umur = 17

# Print agar bisa melihat isi atau nilai variabel
print(makanan)
print(umur)
# Out:
# Pizza
# 17

# %%
nama = "Cindy"

del(nama) # Menghapus variabel yang sudah dibuat
print(nama) # Ketika di print maka error karena variabel sudah terhapus
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_712/179129454.py in <cell line: 0>()
#       2
#       3 del(nama)
# ----> 4 print(nama)
#
# NameError: name 'nama' is not defined

# %% [markdown]
# # Tipe Data

# %% [markdown]
# ## Angka

# %%
harga = 12000 #tipe integer
berat = 23.12 #float #itu 23,12
jarak = 3e3 #float 3000.0, huruf e artinya eksponen 10

# %% [markdown]
# ## Teks

# %%
nama = "Cindy" # String
jenis_kelamin = "P" # Char (Karakter)
bergerak = True # Boolean # Ada 2: True dan False

# %%
nama = "Cindy"
umur = 20
tinggi = 153.5
menikah = False

print("nama : ", nama)
print("umur : ", umur)
print("tinggi : ", tinggi)
if menikah:
  print ("Sudah menikah")
else:
  print ("Belum menikah")
# Out:
# nama :  Cindy
# umur :  20
# tinggi :  153.5
# Belum menikah

# %% [markdown]
# # Input & Output

# %%
pertanyaan = input("Hari ini mau makan apa?") # Masukkan Input

print("Kamu bisa membeli", pertanyaan, "disana") # Munculkan output
# Out:
# Hari ini mau makan apa?Pizza
# Kamu bisa membeli Pizza disana

# %%
# Latihan
print("Hello, world")
# Out:
# Hello, world

# %%
# Latihan
nama = input("Masukkan namamu: ")

print("Halo,", nama)
# Out:
# Masukkan namamu: Cindy
# Halo, Cindy

# %%
# Latihan

a = int(input("Masukkan bilangan: "))
b = int(input("Masukkan bilangan: "))
# jangan lupa pakai int biar tipenya jadi angka bukan string

hasil = a + b

print(hasil)
# Out:
# Masukkan bilangan: 4
# Masukkan bilangan: 2
# 6

# %%
# Latihan

a = input("Masukkan bilangan: ")
b = input("Masukkan bilangan: ")
# ini kalau ga pakai int

hasil = a + b

print(hasil)
# Out:
# Masukkan bilangan: 4
# Masukkan bilangan: 2
# 42

# %%
# Latihan

sisi = int(input("Masukkan sisi persegi: "))

luas = sisi * sisi

print("Luas sisi adalah", luas)
# Out:
# Masukkan sisi persegi: 4
# Luas sisi adalah 16

# %%
# Latihan

panjang = int(input("Masukkan panjang: "))
lebar = int(input("Masukkan lebar: "))

luas = panjang * lebar

print(luas)
# Out:
# Masukkan panjang: 2
# Masukkan lebar: 4
# 8

# %%
# Latihan
nilai1 = float(input("Masukkan nilai: "))
nilai2 = float(input("Masukkan nilai:"))
nilai3 = float(input("Masukkan nilai: "))

ratarata = (nilai1 + nilai2 + nilai3) / 3

print(ratarata)
# Out:
# Masukkan nilai: 89.5
# Masukkan nilai:77.32
# Masukkan nilai: 90.0
# 85.60666666666667

# %%
# Latihan

Nama = input("Masukkan nama: ")
Kelas = input("Masukkan kelas: ")
Jurusan = input("Masukkan jurusan: ")

print("Nama:", Nama)
print("Kelas:", Kelas)
print("Jurusan", Jurusan)
# Out:
# Masukkan nama: Cindy
# Masukkan kelas: A
# Masukkan jurusan: SDT
# Nama: Cindy
# Kelas: A
# Jurusan SDT

# %%
# Latihan
# Merubah menit ke jam

Menit = int(input("Masukkan jumlah menit: "))

Jam = Menit / 60

print("Sekarang sudah", Jam, "jam")
# Out:
# Masukkan jumlah menit: 180
# Sekarang sudah 3.0 jam

# %%
# Latihan
# Menghitung keliling lingkaran

jarijari = int(input("Masukkan jari-jari lingkaran: "))

keliling = 2 * 3.14 * jarijari

print("Keliling lingkaran adalah: ", keliling)
# Out:
# Masukkan jari-jari lingkaran: 7
# Keliling lingkaran adalah:  43.96

# %%
# Latihan
# pakai f biar masukin variabel ke print jadi lebih mudah

nama = input("Nama: ")
umur = input("Umur: ")

print(f"Halo, nama saya {nama} dan umur saya {umur} tahun.")

# %%
# Latihan
# Coba sendiri

nama = input("Masukkan nama: ")

print(f'Halo, nama saya {nama}')
# Out:
# Masukkan nama: Cindy
# Halo, nama saya Cindy

# %%
# Latihan
# Program kasir sederhana

barang = input("Nama barang: ")
harga = int(input("Masukkan harga: "))
jumlah = int(input("Masukkan jumlah: "))

total = harga * jumlah

print("Anda telah membeli", barang)
print("Berikut total yang perlu dibayar", total)
# Out:
# Nama barang: Pepsodent
# Masukkan harga: 15000
# Masukkan jumlah: 2
# Anda telah membeli Pepsodent
# Berikut total yang perlu dibayar 30000
